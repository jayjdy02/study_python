# %%
name = 'Alice'
print(name, type(name))

is_student = True
print(is_student, type(is_student))

age = 20
print(age, type(age))

score = 80.5
print(isinstance(score, int))

print(score, type(score))
# Out:
# Alice <class 'str'>
# True <class 'bool'>
# 20 <class 'int'>
# False
# 80.5 <class 'float'>

# %%
name = 'Lion'
print(name, type(name))

is_man = True
print(is_man, type(is_man))

age = 19
print(age, type(age))

height = 160.5
print(isinstance(height, int))

print(height, type(height))

print(isinstance(height, float))
# Out:
# Lion <class 'str'>
# True <class 'bool'>
# 19 <class 'int'>
# False
# 160.5 <class 'float'>
# True

# %%
first_name = 'John'
last_name = 'Doe'
print(first_name)
print(last_name)

full_name = first_name + last_name
print(full_name)

full_name = first_name + ' ' + last_name
print(full_name)

address = '123 Main Street'
print(address)

address += ', Apartment 4B'
print(address)

employee_age = 28

employee_info = full_name + ' is '

employee_info = full_name + ' is ' + str(employee_age)

employee_info = full_name + ' is ' + str(employee_age) + ' years old'
print(employee_info)

experience_years = 5

experience_info = 'Experience: ' + str(experience_years) + ' years'
print(experience_info)

employee_card = f'Employee: {full_name}'
print(employee_card)

employee_card = f'Employee: {full_name} | Age: {employee_age}'

position = 'Data Analyst'
salary = 75000

employee_card = f'Employee: {full_name} | Age: {employee_age} | Position: {position} | Salary: ${salary}'
print(employee_card)

employee_code = 'DEV-2026-JD-001'
department = employee_code[0:3]
print(department)

year_code = employee_code[4:8]
initials = employee_code[9:11]
print(year_code)
print(initials)

last_three = employee_code[-3:]
print(last_three)
# Out:
# John
# Doe
# JohnDoe
# John Doe
# 123 Main Street
# 123 Main Street, Apartment 4B
# John Doe is 28 years old
# Experience: 5 years
# Employee: John Doe
# Employee: John Doe | Age: 28 | Position: Data Analyst | Salary: $75000
# DEV
# 2026
# JD
# 001

# %%
first_name = 'Lion'
last_name = 'King'
print(first_name)
print(last_name)

full_name = first_name + last_name
print(full_name)

full_name = first_name + ' ' + last_name
print(full_name)

address = '123 Area'
print(address)

address += ', Zone2'
print(address)

employee_age = 19

employee_info = full_name + ' is '

employee_info = full_name + ' is ' + str(employee_age) + ' years old'
print(employee_info)

experience_years = 0

experience_info = 'Experience: ' + str(experience_years) + ' years'
print(experience_info)

employee_card = f'Employee: + {full_name}'
print(employee_card)

employee_card = f'Employee: {full_name} | Age: {employee_age}'
print(employee_card)

position = 'CEO'
salary = 10_000_000
employee_card = f'Employee: {full_name} | Age: {employee_age} | Position: {position} | Salary: ${salary}'
print(employee_card)

position = 'CEO'
salary = 10000000
employee_card = f'Employee: {full_name} | Age: {employee_age} | Position: {position} | Salary: ${salary:,}'
print(employee_card)

employee_code = 'DEV-2026-LO-001'
department = employee_code[0:3]
print(department)

years_code = employee_code[4:8]
print(years_code)

initials = employee_code[9:11]
print(initials)

last_three = employee_code[-3:]
print(last_three)

last_one = employee_code[-1]
print(last_one)
# Out:
# Lion
# King
# LionKing
# Lion King
# 123 Area
# 123 Area, Zone2
# Lion King is 19 years old
# Experience: 0 years
# Employee: + Lion King
# Employee: Lion King | Age: 19
# Employee: Lion King | Age: 19 | Position: CEO | Salary: $10000000
# Employee: Lion King | Age: 19 | Position: CEO | Salary: $10,000,000
# DEV
# 2026
# LO
# 001
# 1
